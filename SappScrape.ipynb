# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import time

driver = webdriver.Chrome()

# Open the main page
base_url = 'https://pk.sapphireonline.pk/'
driver.get('https://pk.sapphireonline.pk/collections/unstitched-eid-2-24')

# Scroll down until all items are loaded
def scroll(driver, timeout):
    scroll_pause_time = timeout
    last_height = driver.execute_script("return document.body.scrollHeight")
    i = 0
    while i < 3:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(scroll_pause_time)
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height
        i += 1

# Call the scroll function
scroll(driver, 1)  # Adjust the timeout as needed

# Extract product links
soup = BeautifulSoup(driver.page_source, 'html.parser')
# print(soup.prettify())

img_links = [img['src'] for img in soup.find_all('img', class_='t4s-product-main-img')]
print(len(img_links))
# print(img_links)
# product_links = [a['href'] for a in soup.find_all('a', class_='grid-view-item__link')]
# print(product_links)
# filtered_links = list(filter(lambda x: "base64" not in x, img_links))
# print(filtered_links)

# # Now visit each product page and extract image paths, title, and price
# for link in product_links:
#     driver.get(base_url + link)
#     # Extract details using Beautiful Soup
#     product_soup = BeautifulSoup(driver.page_source, 'html.parser')
#     # Find the image tag
#     img_tag = product_soup.find('img', alt='slider-img')
    
#     if img_tag:
#         image_url = img_tag['src']
#         print(f"Image URL: {base_url + image_url}")
#     else:
#         print("Image not found on this page.")
#     time.sleep(5)

# # Close the browser
driver.quit()
# Out:
# 96

# %%
filtered_links = list(filter(lambda x: "base64" not in x, img_links))
unique_urls = set(filtered_links)
i = 1
for img in unique_urls:
    img = img.replace("width=1024", "width=256")
    print(i, img)
    i += 1

# urls = list(unique_urls)
# # data = ['//pk.sapphireonline.pk/cdn/shop/files/DSC08521copy.jpg?v=1715952142&width=1024', '//pk.sapphireonline.pk/cdn/shop/files/0U3PESG24V32_1_4c2eb2ac-81c0-4348-9be2-c7eeed577e21.jpg?v=1715000786&width=1024', '//pk.sapphireonline.pk/cdn/shop/files/0U3PEST24V37_2_755f191f-51f3-4449-bde1-4357279216c8.jpg?v=1715000891&width=1024', '//pk.sapphireonline.pk/cdn/shop/files/0U3PESG24V36.jpg?v=1715329703&width=1024', '//pk.sapphireonline.pk/cdn/shop/files/00U2DDY24V34_2.jpg?v=1715171018&width=1024', '//pk.sapphireonline.pk/cdn/shop/files/U3PEST24V318_6.jpg?v=1715170081&width=1024', '//pk.sapphireonline.pk/cdn/shop/files/U3PEDY24V320_3.jpg?v=1715170487&width=1024', '//pk.sapphireonline.pk/cdn/shop/files/00U2TDY24V33_2.jpg?v=1715169686&width=1024', '//pk.sapphireonline.pk/cdn/shop/files/U3PESG24V321_3_0ee33bb3-dc9f-4c10-923d-0ae4f7a17dd5.jpg?v=1715001264&width=1024', '//pk.sapphireonline.pk/cdn/shop/files/02DEDY24WS24_2.jpg?v=1714130272&width=1024', '//pk.sapphireonline.pk/cdn/shop/files/3PEDY24WS211_2.jpg?v=1714133332&width=1024', '//pk.sapphireonline.pk/cdn/shop/files/0U3PDY24V318_2.jpg?v=1715169755&width=1024', '//pk.sapphireonline.pk/cdn/shop/files/0U3PDY24V315_3_1d6a1d16-03b1-4b79-a152-86e2ef7d7c02.jpg?v=1715000514&width=1024', '//pk.sapphireonline.pk/cdn/shop/files/03PEDY24WS21_5.jpg?v=1714132904&width=1024', '//pk.sapphireonline.pk/cdn/shop/files/02TEDY24WS26_2.jpg?v=1714132277&width=1024', '//pk.sapphireonline.pk/cdn/shop/files/0U2TEDY24V38_1_5d3731a7-2f98-4a79-b3eb-7944eba48d07.jpg?v=1715000380&width=1024', '//pk.sapphireonline.pk/cdn/shop/files/00U2TDY24V32_3.jpg?v=1715169674&width=1024', '//pk.sapphireonline.pk/cdn/shop/files/02DEDY24WS23_2.jpg?v=1714130265&width=1024', '//pk.sapphireonline.pk/cdn/shop/files/U3PESG24V313_2.jpg?v=1715170667&width=1024', '//pk.sapphireonline.pk/cdn/shop/files
    
    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Save the image to the directory
        with open(f'image_{index}.jpg', 'wb') as f:
            f.write(response.content)
        print(f"Image {index+1} downloaded successfully.")
    else:
        print(f"Failed to download image {index+1}. Status code: {response.status_code}")
    
    # Introduce a 5-second delay before downloading the next image
    time.sleep(5)
# Out:
# Image 1 downloaded successfully.
# Image 2 downloaded successfully.
# Image 3 downloaded successfully.
# Image 4 downloaded successfully.
# Image 5 downloaded successfully.
# Image 6 downloaded successfully.
# Image 7 downloaded successfully.
# Image 8 downloaded successfully.
# Image 9 downloaded successfully.
# Image 10 downloaded successfully.
# Image 11 downloaded successfully.
# Image 12 downloaded successfully.
# Image 13 downloaded successfully.
# Image 14 downloaded successfully.
# Image 15 downloaded successfully.
# Image 16 downloaded successfully.
# Image 17 downloaded successfully.
# Image 18 downloaded successfully.
# Image 19 downloaded successfully.
# Image 20 downloaded successfully.
# Image 21 downloaded successfully.
# Image 22 downloaded successfully.
# Image 23 downloaded successfully.
# Image 24 downloaded successfully.
# Image 25 downloaded successfully.
# Image 26 downloaded successfully.
# Image 27 downloaded successfully.
# Image 28 downloaded successfully.
# ...

# %%
import requests
from bs4 import BeautifulSoup
from tensorflow.keras.applications import EfficientNetB0  # Replace with DeepFashion2 if available (preferred)
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import os

# %%
def extract_features(img_path, model):
    img = Image.open(img_path)
    img = img.resize((224, 224))  # Resize the image to match the input size expected by the model
    img_data = np.array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features.flatten()

# %%
base_model = ResNet50(weights='imagenet')
model = Model(inputs=base_model.input, outputs=base_model.get_layer('avg_pool').output)
# Out:
# ...
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 132s 1us/step

# %%
def find_similar_images(user_img_path, image_features, model):
    user_features = extract_features(user_img_path, model)
    similarities = cosine_similarity([user_features], image_features)
    return similarities

# %%
from PIL import Image

# %%
image_dir = r"D:\Study\Sem5\ML\Web scrapping\Clothing Store Scrapper\Eid_edit"
    
# List all image files in the directory
image_files = [os.path.join(image_dir, f) for f in os.listdir(image_dir) if f.endswith('.jpg')]

# Extract features from downloaded images
image_features = []
for img_file in image_files:
    features = extract_features(img_file, model)
    image_features.append(features)

image_features = np.array(image_features)

# Example user image path
user_img_path = r"D:\Study\Sem5\ML\Web scrapping\Clothing Store Scrapper\user_images\image_16.jpg"  # Change this to the user's image path
    
# Step 3: Find similar images
similarities = find_similar_images(user_img_path, image_features, model)

# Step 4: Recommendation
top_indices = np.argsort(similarities[0])[-5:][::-1]  # Top 5 similar images
recommended_images = [image_files[i] for i in top_indices]

for img_file in recommended_images:
    print(img_file)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# ...
